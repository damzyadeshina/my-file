# %%
size = input("What size pizza do you want? Small, Medium, or Large: ")
# Out:
# What size pizza do you want? Small, Medium, or Large: size

# %%
add_pepperoni = input("Do you want pepperoni on your pizza? Yes or No: ")
# Out:
# Do you want pepperoni on your pizza? Yes or No: add_pepperoni

# %%
extra_cheese = input("Do you want extra cheese on your pizza? Yes or No: ")

# %%
print(f"\nYou ordered a {size} pizza.")
print(f"Pepperoni: {add_pepperoni}")
print(f"Extra Cheese: {extra_cheese}")
